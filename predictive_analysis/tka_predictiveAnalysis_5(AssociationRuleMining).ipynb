# %%
dataset = [['Milk','Onion','Nutmeg','Kidney Beans','Eggs','yogurt'],
           ['Dill','Onion','Nutmeg','Kidney Beans','Eggs','yogurt'],
           ['Milk','Apple','Kidney Beans','Eggs'],
           ['Milk','Unicorn','Corn','Kidney Beans','yogurt'],
           ['Corn','Onion','Onion','Kidney Beans','Eggs','Ice cream']]

print(dataset)
# Out:
# [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'yogurt'], ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'yogurt'], ['Milk', 'Apple', 'Kidney Beans', 'Eggs'], ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'yogurt'], ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Eggs', 'Ice cream']]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te.fit(dataset)

te_ary = te.transform(dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te.columns_
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['Apple',
#  'Corn',
#  'Dill',
#  'Eggs',
#  'Ice cream',
#  'Kidney Beans',
#  'Milk',
#  'Nutmeg',
#  'Onion',
#  'Unicorn',
#  'yogurt']

# %%
df = pd.DataFrame(te_ary, columns = te.columns_)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
#Most frquent itemsets
from mlxtend.frequent_patterns import apriori
frequent_itemsets = apriori(df, use_colnames=True , min_support=0.4)
frequent_itemsets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support                                     itemsets
# 0       0.4                                       (Corn)
# 1       0.8                                       (Eggs)
# 2       1.0                               (Kidney Beans)
# 3       0.6                                       (Milk)
# 4       0.4                                     (Nutmeg)
# 5       0.6                                      (Onion)
# 6       0.6                                     (yogurt)
# 7       0.4                         (Corn, Kidney Beans)
# 8       0.8                         (Eggs, Kidney Beans)
# ...

# %%
#Calculate confidence,  lift, leverage and conviction of most frequent itemsets

from mlxtend.frequent_patterns import association_rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         antecedents                            consequents  \
# 0            (Corn)                         (Kidney Beans)
# 1    (Kidney Beans)                                 (Corn)
# 2            (Eggs)                         (Kidney Beans)
# 3    (Kidney Beans)                                 (Eggs)
# 4          (Nutmeg)                                 (Eggs)
# ..              ...                                    ...
# 183        (Nutmeg)    (Eggs, yogurt, Onion, Kidney Beans)
# 184        (yogurt)    (Nutmeg, Onion, Eggs, Kidney Beans)
# 185         (Onion)   (Nutmeg, yogurt, Eggs, Kidney Beans)
# ...

# %%
rules.columns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['antecedents', 'consequents', 'antecedent support',
#        'consequent support', 'support', 'confidence', 'lift', 'leverage',
#        'conviction', 'zhangs_metric'],
#       dtype='object')

# %%
result = rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
result
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         antecedents                            consequents  support  \
# 0            (Corn)                         (Kidney Beans)      0.4
# 1    (Kidney Beans)                                 (Corn)      0.4
# 2            (Eggs)                         (Kidney Beans)      0.8
# 3    (Kidney Beans)                                 (Eggs)      0.8
# 4          (Nutmeg)                                 (Eggs)      0.4
# ..              ...                                    ...      ...
# 183        (Nutmeg)    (Eggs, yogurt, Onion, Kidney Beans)      0.4
# 184        (yogurt)    (Nutmeg, Onion, Eggs, Kidney Beans)      0.4
# ...

# %%
result[['antecedents', 'consequents']].to_csv('result.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
product_recommendation = pd.read_csv('result.csv', index_col=0)
product_recommendation
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                      antecedents  \
# 0            frozenset({'Corn'})
# 1    frozenset({'Kidney Beans'})
# 2            frozenset({'Eggs'})
# 3    frozenset({'Kidney Beans'})
# 4          frozenset({'Nutmeg'})
# ..                           ...
# 183        frozenset({'Nutmeg'})
# 184        frozenset({'yogurt'})
# 185         frozenset({'Onion'})
# 186  frozenset({'Kidney Beans'})
# 187          frozenset({'Eggs'})
#
#                                            consequents
# 0                          frozenset({'Kidney Beans'})
# 1                                  frozenset({'Corn'})
# ...

# %%
set(frozenset({'Eggs'}))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'Eggs'}

# %%
product_recommendation['antecedents'] = product_recommendation['antecedents'].astype('str')
product_recommendation['consequents'] = product_recommendation['consequents'].astype('str')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
product_recommendation['antecedents'] = product_recommendation['antecedents'].str.replace('frozenset' ,'')
product_recommendation['consequents'] = product_recommendation['consequents'].str.replace('frozenset' ,'')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
product_recommendation
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             antecedents                                      consequents
# 0            ({'Corn'})                               ({'Kidney Beans'})
# 1    ({'Kidney Beans'})                                       ({'Corn'})
# 2            ({'Eggs'})                               ({'Kidney Beans'})
# 3    ({'Kidney Beans'})                                       ({'Eggs'})
# 4          ({'Nutmeg'})                                       ({'Eggs'})
# ..                  ...                                              ...
# 183        ({'Nutmeg'})    ({'Eggs', 'yogurt', 'Onion', 'Kidney Beans'})
# ...

# %%
basket = 'yogurt'

#make recommendation using product_recommendation if in a basket 'yogurt' is purchased

product_recommendation[product_recommendation['antecedents'].str.contains(basket)]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                       antecedents  \
# 14                   ({'yogurt'})
# 16                   ({'yogurt'})
# 21                   ({'yogurt'})
# 22                   ({'yogurt'})
# 38           ({'yogurt', 'Eggs'})
# ..                            ...
# 173        ({'Nutmeg', 'yogurt'})
# 177         ({'yogurt', 'Onion'})
# 178  ({'yogurt', 'Kidney Beans'})
# 179          ({'yogurt', 'Eggs'})
# 184                  ({'yogurt'})
#
#                                        consequents
# 14                              ({'Kidney Beans'})
# 16                                      ({'Milk'})
# ...

# %%
product_recommendation['antecedents'] = product_recommendation['antecedents'].apply(lambda x : x[1:-1])
product_recommendation['consequents'] = product_recommendation['consequents'].apply(lambda x : x[1:-1])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
product_recommendation.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         antecedents       consequents
# 0          {'Corn'}  {'Kidney Beans'}
# 1  {'Kidney Beans'}          {'Corn'}
# 2          {'Eggs'}  {'Kidney Beans'}
# 3  {'Kidney Beans'}          {'Eggs'}
# 4        {'Nutmeg'}          {'Eggs'}

# %%
basket = "{'Eggs'}"
product_recommendation[product_recommendation['antecedents'] == basket]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     antecedents                                    consequents
# 2      {'Eggs'}                               {'Kidney Beans'}
# 5      {'Eggs'}                                     {'Nutmeg'}
# 6      {'Eggs'}                                      {'Onion'}
# 30     {'Eggs'}                     {'Nutmeg', 'Kidney Beans'}
# 35     {'Eggs'}                      {'Onion', 'Kidney Beans'}
# 43     {'Eggs'}                            {'Nutmeg', 'Onion'}
# 51     {'Eggs'}                           {'Nutmeg', 'yogurt'}
# 55     {'Eggs'}                            {'yogurt', 'Onion'}
# ...

# %%
product_recommendation[product_recommendation['antecedents'] == basket].consequents
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2                                   {'Kidney Beans'}
# 5                                         {'Nutmeg'}
# 6                                          {'Onion'}
# 30                        {'Nutmeg', 'Kidney Beans'}
# 35                         {'Onion', 'Kidney Beans'}
# 43                               {'Nutmeg', 'Onion'}
# 51                              {'Nutmeg', 'yogurt'}
# 55                               {'yogurt', 'Onion'}
# 98               {'Nutmeg', 'Onion', 'Kidney Beans'}
# 114             {'Nutmeg', 'yogurt', 'Kidney Beans'}
# 126              {'yogurt', 'Onion', 'Kidney Beans'}
# ...
